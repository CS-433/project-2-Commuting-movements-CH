# %% [markdown]
# # XGBoost Algorithm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score, f1_score, confusion_matrix, classification_report,  roc_auc_score
import os
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split
from scipy import stats
import seaborn as sns
from itertools import product
import time
import json
from sklearn.model_selection import RandomizedSearchCV

# %%
import xgboost as xgb
from functions import *

# %% [markdown]
# ## Load data

# %%
base_path = '/Users/leilapaolini/Documents/data'
full_path = os.path.join(base_path, 'data_y.npy')
data = np.load(full_path, allow_pickle=True)

print(f"Data type: {type(data)}")
print(f"Data shape: {data.shape if hasattr(data, 'shape') else 'N/A'}")
# Out:
# Data type: <class 'numpy.ndarray'>
# Data shape: (9618522, 35)

# %%
df = pd.DataFrame(data, columns=['commune_1', 'commune_2', 'distance', 'year', 'pop_1', 'pop_2',
       'T_Mann', 'T_Frau', 'Etr_Total', 'Accidents dégâts matériels',
       'Accidents avec dommages corporels', 'Morts', 'GEM_FLAECH',
       'EINWOHNERZ', '0-25', '25-65', '65+', 'canton_code', 'unemployment',
       'gdp', 'T_Mann_2', 'T_Frau_2', 'Etr_Total_2',
       'Accidents dégâts matériels_2', 'Accidents avec dommages corporels_2',
       'Morts_2', 'GEM_FLAECH_2', 'EINWOHNERZ_2', '0-25_2', '25-65_2', '65+_2',
       'canton_code_2', 'unemployment_2', 'gdp_2', 'flow'])

df.head()
# Out:
#    commune_1  commune_2     distance    year   pop_1    pop_2  T_Mann  T_Frau  \
# 0        1.0        2.0  3062.019741  2018.0  1982.0  12229.0   982.0  1000.0
# 1        1.0        2.0  3062.019741  2020.0  1982.0  12229.0   994.0  1020.0
# 2        1.0        3.0  4916.726674  2018.0  1982.0   5548.0   982.0  1000.0
# 3        1.0        3.0  4916.726674  2020.0  1982.0   5548.0   994.0  1020.0
# 4        1.0        4.0  4951.312604  2018.0  1982.0   3701.0   982.0  1000.0
#
#    Etr_Total  Accidents dégâts matériels  ...  Morts_2  GEM_FLAECH_2  \
# 0      135.0                         3.0  ...      0.0        1059.0
# 1      143.0                         7.0  ...      0.0        1059.0
# 2      135.0                         3.0  ...      0.0         743.0
# 3      143.0                         7.0  ...      1.0         743.0
# 4      135.0                         3.0  ...      1.0        1360.0
#
#    EINWOHNERZ_2  0-25_2  25-65_2   65+_2  canton_code_2  unemployment_2  \
# 0       11900.0  3062.0   6981.0  2472.0            1.0    21793.250000
# 1       12229.0  2951.0   7052.0  2551.0            1.0    26155.333333
# 2        5435.0  1532.0   3151.0   997.0            1.0    21793.250000
# 3        5548.0  1551.0   3107.0  1050.0            1.0    26155.333333
# 4        3571.0   971.0   2072.0   739.0            1.0    21793.250000
#
#           gdp_2   flow
# 0  156883.07738  122.0
# 1  149208.52863   79.0
# 2  156883.07738   10.0
# 3  149208.52863   29.0
# 4  156883.07738   17.0
#
# [5 rows x 35 columns]

# %%
n_total = len(df)
n_zero = (df['flow'] == 0).sum()

percent_zero = 100 * n_zero / n_total

print(f"Zero flows: {n_zero} / {n_total} ({percent_zero:.2f}%)")
# Out:
# Zero flows: 9492963 / 9618522 (98.69%)

# %% [markdown]
# ## Data preparation

# %%
not_log_transform = ['commune_1', 'commune_2', 'Morts','Morts_2', 'year', 'canton_code', 'unemployment','gdp','canton_code_2', 'unemployment_2', 'gdp_2', 'flow']
to_log = [col for col in df.columns if col not in not_log_transform]

df = features_change(df, to_log, "log")

# %%
df = features_engineering(df)
# Out:
# Column for multiplied population added
# Column for population ratio added
# Column for difference between gdp of the communes added
# Column for distance between the communes squared added
# Column for gravitation added

# %% [markdown]
# notice that we do not normalise as xgboost does not need normalisation

# %%
drop_features = ['commune_1', 'commune_2', 'flow']
X_train, y_train, X_val, y_val, X_test, y_test = build_train_test_val(df, 
                                                                      test_canton_ids=[3], 
                                                                      val_canton_ids=[19], 
                                                                      zero_drop_ratio=0, 
                                                                      random_state=37, 
                                                                      features=drop_features, 
                                                                      classify= True)
# Out:
# Splitting with canton [3] as test set:
# Total flows: 9,618,522
# Train size: 8,912,666 rows (92.7%)
# Test size: 705,856 rows (7.3%)
# Splitting with canton [19] as test set:
# Total flows: 8,912,666
# Train size: 7,227,626 rows (81.1%)
# Test size: 1,685,040 rows (18.9%)
# Dropping 0% of zeros in training data
# Flow reclassified as 1: flow present, 0: no flow
# Flow reclassified as 1: flow present, 0: no flow
# Flow reclassified as 1: flow present, 0: no flow

# %%
X_val.head()
# Out:
#         distance     pop_1     pop_2    T_Mann    T_Frau  Etr_Total  \
# 2458  109.569788  7.591862  9.976087  6.889591  6.907755   4.905275
# 2459  109.569788  7.591862  9.976087  6.901737  6.927558   4.962845
# 2460  109.248387  7.591862  7.359468  6.889591  6.907755   4.905275
# 2461  109.248387  7.591862  7.359468  6.901737  6.927558   4.962845
# 2462  108.309143  7.591862  8.982938  6.889591  6.907755   4.905275
#
#       Accidents dégâts matériels  Accidents avec dommages corporels  Morts  \
# 2458                    1.098616                           0.693152    0.0
# 2459                    1.945912                           1.609440    0.0
# 2460                    1.098616                           0.693152    0.0
# 2461                    1.945912                           1.609440    0.0
# 2462                    1.098616                           0.693152    0.0
#
#       GEM_FLAECH  ...     65+_2  canton_code_2  unemployment_2        gdp_2  \
# 2458    6.673298  ...  8.385717           19.0     9734.916667  43687.13571
# 2459    6.673298  ...  8.392310           19.0    12802.583333  44108.19224
# 2460    6.673298  ...  6.063785           19.0     9734.916667  43687.13571
# 2461    6.673298  ...  6.142037           19.0    12802.583333  44108.19224
# 2462    6.673298  ...  7.239215           19.0     9734.916667  43687.13571
#
#       pop_1_x_pop_2  pop_1/pop_2_ratio  gdp_minus_gdp_2  gravity_raw  \
# 2458      75.737075           0.761005     113195.94167     0.006309
# 2459      75.737075           0.761005     105100.33639     0.006309
# 2460      55.872061           1.031576     113195.94167     0.004681
# 2461      55.872061           1.031576     105100.33639     0.004681
# 2462      68.197221           0.845141     113195.94167     0.005813
#
#       year_2018.0  year_2020.0
# 2458            1            0
# 2459            0            1
# 2460            1            0
# 2461            0            1
# 2462            1            0
#
# [5 rows x 37 columns]

# %%
# we do one-hot encoding for canton ids since they are categorical features 

X_train = pd.get_dummies(
    X_train,
    columns=["canton_code", "canton_code_2"],
    prefix=["canton_1", "canton_2"],
    drop_first=False
)

X_test = pd.get_dummies(
    X_test,
    columns=["canton_code", "canton_code_2"],
    prefix=["canton_1", "canton_2"],
    drop_first=False
)

X_val = pd.get_dummies(
    X_val,
    columns=["canton_code", "canton_code_2"],
    prefix=["canton_1", "canton_2"],
    drop_first=False
)

X_train.head()
# Out:
#      distance     pop_1     pop_2    T_Mann    T_Frau  Etr_Total  \
# 0  137.799059  8.319474  6.728629  7.601402  7.650645   5.950643
# 1  121.479057  9.008469  6.542472  8.341649  8.314342   7.058758
# 2  105.489526  7.271009  6.917706  6.573680  6.598509   4.820282
# 3  108.055025  5.587249  6.359574  5.023881  5.010635   2.890372
# 4  116.318767  5.384495  6.196444  4.634729  4.753590   2.639058
#
#    Accidents dégâts matériels  Accidents avec dommages corporels  Morts  \
# 0                    2.639058                           2.079443    0.0
# 1                    4.804021                           3.496508    0.0
# 2                    0.000010                         -11.512925    0.0
# 3                    0.693152                         -11.512925    0.0
# 4                  -11.512925                           0.000010    0.0
#
#    GEM_FLAECH  ...  canton_2_16.0  canton_2_17.0  canton_2_18.0  \
# 0    6.381816  ...          False          False          False
# 1    7.123673  ...          False          False          False
# 2    5.587249  ...          False          False          False
# 3    5.937536  ...          False          False          False
# 4    6.666957  ...          False          False          False
#
#    canton_2_20.0  canton_2_21.0  canton_2_22.0  canton_2_23.0  canton_2_24.0  \
# 0          False          False          False          False          False
# 1           True          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    canton_2_25.0  canton_2_26.0
# 0          False          False
# 1          False          False
# 2          False           True
# 3          False          False
# 4          False          False
#
# [5 rows x 83 columns]

# %%
print(np.unique(y_train, return_counts=True))
print(np.unique(y_val, return_counts=True))
print(np.unique(y_test, return_counts=True))
# Out:
# (array([0, 1]), array([7132444,   95182]))
# (array([0, 1]), array([1664686,   20354]))
# (array([0, 1]), array([695833,  10023]))

# %%
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (7227626, 83)
# (705856, 87)
# (1685040, 85)

# %%
X_val  = X_val.reindex(columns=X_train.columns, fill_value=0)
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

print(X_train.shape, X_val.shape, X_test.shape)

assert X_train.shape[1] == X_val.shape[1] == X_test.shape[1]
assert X_train.columns.equals(X_val.columns)
assert X_train.columns.equals(X_test.columns)
# Out:
# (7227626, 83) (1685040, 83) (705856, 83)

# %% [markdown]
# ## XGBoost Classifier

# %% [markdown]
# ### Initial models

# %%
# We start with a basic model 

clf = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    random_state=42
)

clf.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],
    verbose=True
)

y_val_proba = clf.predict_proba(X_val)[:, 1]
y_val_pred = (y_val_proba >= 0.5).astype(int)

print(classification_report(y_val, y_val_pred))
print(confusion_matrix(y_val, y_val_pred))
# Out:
# [0]	validation_0-auc:0.99136
# [1]	validation_0-auc:0.99236
# [2]	validation_0-auc:0.99250
# [3]	validation_0-auc:0.99253
# [4]	validation_0-auc:0.99260
# [5]	validation_0-auc:0.99267
# [6]	validation_0-auc:0.99286
# [7]	validation_0-auc:0.99292
# [8]	validation_0-auc:0.99296
# [9]	validation_0-auc:0.99300
# [10]	validation_0-auc:0.99306
# [11]	validation_0-auc:0.99309
# [12]	validation_0-auc:0.99311
# [13]	validation_0-auc:0.99312
# [14]	validation_0-auc:0.99316
# [15]	validation_0-auc:0.99317
# [16]	validation_0-auc:0.99319
# [17]	validation_0-auc:0.99318
# [18]	validation_0-auc:0.99317
# [19]	validation_0-auc:0.99318
# [20]	validation_0-auc:0.99321
# [21]	validation_0-auc:0.99322
# [22]	validation_0-auc:0.99323
# [23]	validation_0-auc:0.99325
# [24]	validation_0-auc:0.99328
# [25]	validation_0-auc:0.99328
# [26]	validation_0-auc:0.99333
# [27]	validation_0-auc:0.99335
# [28]	validation_0-auc:0.99339
# [29]	validation_0-auc:0.99340
# [30]	validation_0-auc:0.99341
# [31]	validation_0-auc:0.99343
# [32]	validation_0-auc:0.99345
# [33]	validation_0-auc:0.99347
# [34]	validation_0-auc:0.99347
# [35]	validation_0-auc:0.99347
# [36]	validation_0-auc:0.99346
# [37]	validation_0-auc:0.99346
# [38]	validation_0-auc:0.99348
# [39]	validation_0-auc:0.99349
# [40]	validation_0-auc:0.99349
# [41]	validation_0-auc:0.99349
# [42]	validation_0-auc:0.99350
# [43]	validation_0-auc:0.99352
# [44]	validation_0-auc:0.99354
# [45]	validation_0-auc:0.99353
# [46]	validation_0-auc:0.99354
# [47]	validation_0-auc:0.99354
# [48]	validation_0-auc:0.99356
# [49]	validation_0-auc:0.99357
# [50]	validation_0-auc:0.99357
# [51]	validation_0-auc:0.99358
# [52]	validation_0-auc:0.99357
# [53]	validation_0-auc:0.99357
# [54]	validation_0-auc:0.99358
# [55]	validation_0-auc:0.99359
# [56]	validation_0-auc:0.99360
# [57]	validation_0-auc:0.99360
# [58]	validation_0-auc:0.99361
# [59]	validation_0-auc:0.99365
# [60]	validation_0-auc:0.99366
# [61]	validation_0-auc:0.99367
# [62]	validation_0-auc:0.99370
# [63]	validation_0-auc:0.99370
# [64]	validation_0-auc:0.99376
# [65]	validation_0-auc:0.99377
# [66]	validation_0-auc:0.99380
# [67]	validation_0-auc:0.99381
# [68]	validation_0-auc:0.99383
# [69]	validation_0-auc:0.99383
# [70]	validation_0-auc:0.99384
# [71]	validation_0-auc:0.99390
# [72]	validation_0-auc:0.99391
# [73]	validation_0-auc:0.99391
# [74]	validation_0-auc:0.99391
# [75]	validation_0-auc:0.99392
# [76]	validation_0-auc:0.99392
# [77]	validation_0-auc:0.99395
# [78]	validation_0-auc:0.99397
# [79]	validation_0-auc:0.99401
# [80]	validation_0-auc:0.99401
# [81]	validation_0-auc:0.99401
# [82]	validation_0-auc:0.99401
# [83]	validation_0-auc:0.99401
# [84]	validation_0-auc:0.99402
# [85]	validation_0-auc:0.99402
# [86]	validation_0-auc:0.99402
# [87]	validation_0-auc:0.99403
# [88]	validation_0-auc:0.99403
# [89]	validation_0-auc:0.99404
# [90]	validation_0-auc:0.99405
# [91]	validation_0-auc:0.99407
# [92]	validation_0-auc:0.99407
# [93]	validation_0-auc:0.99408
# [94]	validation_0-auc:0.99408
# [95]	validation_0-auc:0.99409
# [96]	validation_0-auc:0.99410
# [97]	validation_0-auc:0.99414
# [98]	validation_0-auc:0.99415
# [99]	validation_0-auc:0.99416
# [100]	validation_0-auc:0.99416
# [101]	validation_0-auc:0.99416
# [102]	validation_0-auc:0.99416
# [103]	validation_0-auc:0.99416
# [104]	validation_0-auc:0.99416
# [105]	validation_0-auc:0.99417
# [106]	validation_0-auc:0.99417
# [107]	validation_0-auc:0.99417
# [108]	validation_0-auc:0.99417
# [109]	validation_0-auc:0.99417
# [110]	validation_0-auc:0.99418
# [111]	validation_0-auc:0.99419
# [112]	validation_0-auc:0.99419
# [113]	validation_0-auc:0.99420
# [114]	validation_0-auc:0.99420
# [115]	validation_0-auc:0.99421
# [116]	validation_0-auc:0.99422
# [117]	validation_0-auc:0.99422
# [118]	validation_0-auc:0.99422
# [119]	validation_0-auc:0.99422
# [120]	validation_0-auc:0.99422
# [121]	validation_0-auc:0.99422
# [122]	validation_0-auc:0.99422
# [123]	validation_0-auc:0.99422
# [124]	validation_0-auc:0.99423
# [125]	validation_0-auc:0.99423
# [126]	validation_0-auc:0.99424
# [127]	validation_0-auc:0.99424
# [128]	validation_0-auc:0.99425
# [129]	validation_0-auc:0.99425
# [130]	validation_0-auc:0.99425
# [131]	validation_0-auc:0.99425
# [132]	validation_0-auc:0.99426
# [133]	validation_0-auc:0.99426
# [134]	validation_0-auc:0.99427
# [135]	validation_0-auc:0.99427
# [136]	validation_0-auc:0.99428
# [137]	validation_0-auc:0.99428
# [138]	validation_0-auc:0.99428
# [139]	validation_0-auc:0.99429
# [140]	validation_0-auc:0.99429
# [141]	validation_0-auc:0.99429
# [142]	validation_0-auc:0.99430
# [143]	validation_0-auc:0.99431
# [144]	validation_0-auc:0.99432
# [145]	validation_0-auc:0.99432
# [146]	validation_0-auc:0.99432
# [147]	validation_0-auc:0.99432
# [148]	validation_0-auc:0.99432
# [149]	validation_0-auc:0.99433
# [150]	validation_0-auc:0.99434
# [151]	validation_0-auc:0.99433
# [152]	validation_0-auc:0.99434
# [153]	validation_0-auc:0.99433
# [154]	validation_0-auc:0.99433
# [155]	validation_0-auc:0.99433
# [156]	validation_0-auc:0.99434
# [157]	validation_0-auc:0.99434
# [158]	validation_0-auc:0.99435
# [159]	validation_0-auc:0.99435
# [160]	validation_0-auc:0.99435
# [161]	validation_0-auc:0.99435
# [162]	validation_0-auc:0.99435
# [163]	validation_0-auc:0.99435
# [164]	validation_0-auc:0.99437
# [165]	validation_0-auc:0.99437
# [166]	validation_0-auc:0.99437
# [167]	validation_0-auc:0.99438
# [168]	validation_0-auc:0.99438
# [169]	validation_0-auc:0.99438
# [170]	validation_0-auc:0.99438
# [171]	validation_0-auc:0.99438
# [172]	validation_0-auc:0.99438
# [173]	validation_0-auc:0.99438
# [174]	validation_0-auc:0.99439
# [175]	validation_0-auc:0.99439
# [176]	validation_0-auc:0.99439
# [177]	validation_0-auc:0.99439
# [178]	validation_0-auc:0.99439
# [179]	validation_0-auc:0.99439
# [180]	validation_0-auc:0.99439
# [181]	validation_0-auc:0.99440
# [182]	validation_0-auc:0.99441
# [183]	validation_0-auc:0.99441
# [184]	validation_0-auc:0.99442
# [185]	validation_0-auc:0.99442
# [186]	validation_0-auc:0.99443
# [187]	validation_0-auc:0.99443
# [188]	validation_0-auc:0.99445
# [189]	validation_0-auc:0.99445
# [190]	validation_0-auc:0.99445
# [191]	validation_0-auc:0.99445
# [192]	validation_0-auc:0.99445
# [193]	validation_0-auc:0.99445
# [194]	validation_0-auc:0.99445
# [195]	validation_0-auc:0.99445
# [196]	validation_0-auc:0.99446
# [197]	validation_0-auc:0.99447
# [198]	validation_0-auc:0.99447
# [199]	validation_0-auc:0.99447
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   3329376
#            1       0.68      0.69      0.69     40704
#
#     accuracy                           0.99   3370080
#    macro avg       0.84      0.84      0.84   3370080
# weighted avg       0.99      0.99      0.99   3370080
#
# [[3316320   13056]
#  [  12512   28192]]

# %%
n_neg = (y_train == 0).sum()
n_pos = (y_train == 1).sum()

print("Negatives:", n_neg)
print("Positives:", n_pos)
print("Ratio (neg / pos):", n_neg / n_pos)
# Out:
# Negatives: 14264892
# Positives: 190360
# Ratio (neg / pos): 74.93639420046229

# %%
# we add scale_pos_weight to handle class imbalance 

scale_pos_weight = n_neg / n_pos

clf_weighted = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    scale_pos_weight=scale_pos_weight,
    random_state=42
)

clf_weighted.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],
    verbose=True
)

y_val_proba_w = clf_weighted.predict_proba(X_val)[:, 1]
y_val_pred_w = (y_val_proba_w >= 0.5).astype(int)

print(classification_report(y_val, y_val_pred_w))
print(confusion_matrix(y_val, y_val_pred_w))
# Out:
# [0]	validation_0-auc:0.98977
# [1]	validation_0-auc:0.99035
# [2]	validation_0-auc:0.99100
# [3]	validation_0-auc:0.99189
# [4]	validation_0-auc:0.99194
# [5]	validation_0-auc:0.99234
# [6]	validation_0-auc:0.99246
# [7]	validation_0-auc:0.99248
# [8]	validation_0-auc:0.99250
# [9]	validation_0-auc:0.99263
# [10]	validation_0-auc:0.99268
# [11]	validation_0-auc:0.99267
# [12]	validation_0-auc:0.99272
# [13]	validation_0-auc:0.99289
# [14]	validation_0-auc:0.99287
# [15]	validation_0-auc:0.99296
# [16]	validation_0-auc:0.99299
# [17]	validation_0-auc:0.99311
# [18]	validation_0-auc:0.99325
# [19]	validation_0-auc:0.99323
# [20]	validation_0-auc:0.99331
# [21]	validation_0-auc:0.99336
# [22]	validation_0-auc:0.99340
# [23]	validation_0-auc:0.99347
# [24]	validation_0-auc:0.99348
# [25]	validation_0-auc:0.99357
# [26]	validation_0-auc:0.99363
# [27]	validation_0-auc:0.99362
# [28]	validation_0-auc:0.99363
# [29]	validation_0-auc:0.99366
# [30]	validation_0-auc:0.99371
# [31]	validation_0-auc:0.99372
# [32]	validation_0-auc:0.99373
# [33]	validation_0-auc:0.99376
# [34]	validation_0-auc:0.99379
# [35]	validation_0-auc:0.99382
# [36]	validation_0-auc:0.99383
# [37]	validation_0-auc:0.99385
# [38]	validation_0-auc:0.99389
# [39]	validation_0-auc:0.99391
# [40]	validation_0-auc:0.99395
# [41]	validation_0-auc:0.99397
# [42]	validation_0-auc:0.99399
# [43]	validation_0-auc:0.99399
# [44]	validation_0-auc:0.99402
# [45]	validation_0-auc:0.99404
# [46]	validation_0-auc:0.99404
# [47]	validation_0-auc:0.99408
# [48]	validation_0-auc:0.99411
# [49]	validation_0-auc:0.99413
# [50]	validation_0-auc:0.99417
# [51]	validation_0-auc:0.99422
# [52]	validation_0-auc:0.99422
# [53]	validation_0-auc:0.99426
# [54]	validation_0-auc:0.99428
# [55]	validation_0-auc:0.99430
# [56]	validation_0-auc:0.99432
# [57]	validation_0-auc:0.99433
# [58]	validation_0-auc:0.99433
# [59]	validation_0-auc:0.99434
# [60]	validation_0-auc:0.99435
# [61]	validation_0-auc:0.99435
# [62]	validation_0-auc:0.99438
# [63]	validation_0-auc:0.99439
# [64]	validation_0-auc:0.99442
# [65]	validation_0-auc:0.99442
# [66]	validation_0-auc:0.99443
# [67]	validation_0-auc:0.99444
# [68]	validation_0-auc:0.99444
# [69]	validation_0-auc:0.99444
# [70]	validation_0-auc:0.99445
# [71]	validation_0-auc:0.99446
# [72]	validation_0-auc:0.99446
# [73]	validation_0-auc:0.99447
# [74]	validation_0-auc:0.99448
# [75]	validation_0-auc:0.99449
# [76]	validation_0-auc:0.99449
# [77]	validation_0-auc:0.99449
# [78]	validation_0-auc:0.99449
# [79]	validation_0-auc:0.99450
# [80]	validation_0-auc:0.99450
# [81]	validation_0-auc:0.99452
# [82]	validation_0-auc:0.99452
# [83]	validation_0-auc:0.99453
# [84]	validation_0-auc:0.99454
# [85]	validation_0-auc:0.99453
# [86]	validation_0-auc:0.99454
# [87]	validation_0-auc:0.99456
# [88]	validation_0-auc:0.99457
# [89]	validation_0-auc:0.99457
# [90]	validation_0-auc:0.99457
# [91]	validation_0-auc:0.99458
# [92]	validation_0-auc:0.99458
# [93]	validation_0-auc:0.99459
# [94]	validation_0-auc:0.99459
# [95]	validation_0-auc:0.99459
# [96]	validation_0-auc:0.99460
# [97]	validation_0-auc:0.99460
# [98]	validation_0-auc:0.99460
# [99]	validation_0-auc:0.99460
# [100]	validation_0-auc:0.99460
# [101]	validation_0-auc:0.99461
# [102]	validation_0-auc:0.99462
# [103]	validation_0-auc:0.99463
# [104]	validation_0-auc:0.99462
# [105]	validation_0-auc:0.99463
# [106]	validation_0-auc:0.99462
# [107]	validation_0-auc:0.99463
# [108]	validation_0-auc:0.99462
# [109]	validation_0-auc:0.99462
# [110]	validation_0-auc:0.99463
# [111]	validation_0-auc:0.99463
# [112]	validation_0-auc:0.99463
# [113]	validation_0-auc:0.99464
# [114]	validation_0-auc:0.99464
# [115]	validation_0-auc:0.99464
# [116]	validation_0-auc:0.99463
# [117]	validation_0-auc:0.99465
# [118]	validation_0-auc:0.99465
# [119]	validation_0-auc:0.99465
# [120]	validation_0-auc:0.99465
# [121]	validation_0-auc:0.99466
# [122]	validation_0-auc:0.99465
# [123]	validation_0-auc:0.99464
# [124]	validation_0-auc:0.99464
# [125]	validation_0-auc:0.99463
# [126]	validation_0-auc:0.99463
# [127]	validation_0-auc:0.99463
# [128]	validation_0-auc:0.99463
# [129]	validation_0-auc:0.99464
# [130]	validation_0-auc:0.99464
# [131]	validation_0-auc:0.99466
# [132]	validation_0-auc:0.99465
# [133]	validation_0-auc:0.99466
# [134]	validation_0-auc:0.99466
# [135]	validation_0-auc:0.99466
# [136]	validation_0-auc:0.99467
# [137]	validation_0-auc:0.99467
# [138]	validation_0-auc:0.99467
# [139]	validation_0-auc:0.99467
# [140]	validation_0-auc:0.99468
# [141]	validation_0-auc:0.99468
# [142]	validation_0-auc:0.99469
# [143]	validation_0-auc:0.99469
# [144]	validation_0-auc:0.99469
# [145]	validation_0-auc:0.99469
# [146]	validation_0-auc:0.99470
# [147]	validation_0-auc:0.99470
# [148]	validation_0-auc:0.99470
# [149]	validation_0-auc:0.99471
# [150]	validation_0-auc:0.99471
# [151]	validation_0-auc:0.99470
# [152]	validation_0-auc:0.99470
# [153]	validation_0-auc:0.99470
# [154]	validation_0-auc:0.99470
# [155]	validation_0-auc:0.99470
# [156]	validation_0-auc:0.99471
# [157]	validation_0-auc:0.99471
# [158]	validation_0-auc:0.99470
# [159]	validation_0-auc:0.99470
# [160]	validation_0-auc:0.99469
# [161]	validation_0-auc:0.99471
# [162]	validation_0-auc:0.99471
# [163]	validation_0-auc:0.99471
# [164]	validation_0-auc:0.99472
# [165]	validation_0-auc:0.99472
# [166]	validation_0-auc:0.99472
# [167]	validation_0-auc:0.99472
# [168]	validation_0-auc:0.99474
# [169]	validation_0-auc:0.99475
# [170]	validation_0-auc:0.99475
# [171]	validation_0-auc:0.99475
# [172]	validation_0-auc:0.99475
# [173]	validation_0-auc:0.99475
# [174]	validation_0-auc:0.99475
# [175]	validation_0-auc:0.99475
# [176]	validation_0-auc:0.99475
# [177]	validation_0-auc:0.99475
# [178]	validation_0-auc:0.99475
# [179]	validation_0-auc:0.99477
# [180]	validation_0-auc:0.99476
# [181]	validation_0-auc:0.99476
# [182]	validation_0-auc:0.99476
# [183]	validation_0-auc:0.99476
# [184]	validation_0-auc:0.99477
# [185]	validation_0-auc:0.99477
# [186]	validation_0-auc:0.99478
# [187]	validation_0-auc:0.99478
# [188]	validation_0-auc:0.99479
# [189]	validation_0-auc:0.99479
# [190]	validation_0-auc:0.99479
# [191]	validation_0-auc:0.99479
# [192]	validation_0-auc:0.99480
# [193]	validation_0-auc:0.99479
# [194]	validation_0-auc:0.99479
# [195]	validation_0-auc:0.99480
# [196]	validation_0-auc:0.99480
# [197]	validation_0-auc:0.99480
# [198]	validation_0-auc:0.99480
# [199]	validation_0-auc:0.99480
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98   3329376
#            1       0.22      0.98      0.36     40704
#
#     accuracy                           0.96   3370080
#    macro avg       0.61      0.97      0.67   3370080
# weighted avg       0.99      0.96      0.97   3370080
#
# [[3184812  144564]
#  [    688   40016]]

# %%
# we tune threshold for baseline 
thresholds = np.linspace(0.01, 0.99, 200)
f1_scores = []

for t in thresholds:
    preds = (y_val_proba >= t).astype(int)
    f1_scores.append(f1_score(y_val, preds))

best_t_baseline = thresholds[np.argmax(f1_scores)]
best_f1_baseline = max(f1_scores)

print("Best threshold (baseline):", best_t_baseline)
print("Best F1 (baseline):", best_f1_baseline)
# Out:
# Best threshold (baseline): 0.5369346733668342
# Best F1 (baseline): 0.6884701501924577

# %%
f1_scores_w = []

for t in thresholds:
    preds = (y_val_proba_w >= t).astype(int)
    f1_scores_w.append(f1_score(y_val, preds))

best_t_weighted = thresholds[np.argmax(f1_scores_w)]
best_f1_weighted = max(f1_scores_w)

print("Best threshold (weighted):", best_t_weighted)
print("Best F1 (weighted):", best_f1_weighted)
# Out:
# Best threshold (weighted): 0.9801507537688443
# Best F1 (weighted): 0.7008716786240097

# %%
best_threshold = best_t_weighted
final_clf = clf_weighted

# %%
y_test_proba = final_clf.predict_proba(X_test)[:, 1]
y_test_pred = (y_test_proba >= best_threshold).astype(int)

print(classification_report(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1391669
#            1       0.73      0.69      0.71     20043
#
#     accuracy                           0.99   1411712
#    macro avg       0.86      0.84      0.85   1411712
# weighted avg       0.99      0.99      0.99   1411712
#
# [[1386495    5174]
#  [   6303   13740]]

# %% [markdown]
# ### Grid search

# %%
n_neg = np.sum(y_train == 0)
n_pos = np.sum(y_train == 1)

scale_pos_weight = n_neg / n_pos
print(f"scale_pos_weight = {scale_pos_weight:.2f}")
# Out:
# scale_pos_weight = 74.94

# %%
print(X_train.shape)
# Out:
# (14455252, 83)

# %%
# since it takes a long time and much memory we do the grid search on a portion of the train data 

X_tune, _, y_tune, _ = train_test_split(
    X_train,
    y_train,
    train_size=0.5,
    stratify=y_train,
    random_state=37
)

print("Tuning set shape:", X_tune.shape)
print("Positive ratio (tune):", y_tune.mean())
print("Positive ratio (train):", y_train.mean())
# Out:
# Tuning set shape: (7227626, 83)
# Positive ratio (tune): 0.013168916045185514
# Positive ratio (train): 0.013168916045185514

# %%
param_distributions = {
    'learning_rate': [0.03, 0.05, 0.1],
    'max_depth': [4, 5, 6, 7],
    'n_estimators': [200, 300],
    'subsample': [0.8, 0.9],
    'colsample_bytree': [0.8, 0.9],
    'min_child_weight': [3, 5],
    'gamma': [0, 0.1, 0.2],
}

base_clf = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    scale_pos_weight=scale_pos_weight,
    tree_method='hist',
    random_state=37,
    n_jobs=-1
)

# %%
# Two-phase hyperparameter tuning approach : 

# phase 1: COARSE RANDOM SEARCH


# we start with random search to explore
random_search = RandomizedSearchCV(
    estimator=base_clf,
    param_distributions=param_distributions,
    n_iter=20,
    scoring='roc_auc',
    cv=3,
    verbose=1,
    n_jobs=1,          # before was -1 but changed it to avoid memory explosion
    refit=True,
    random_state=37
)
print("Phase 1: Random Search on tune set")
random_search.fit(X_tune, y_tune)
# Out:
# Phase 1: Random Search on tune set
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='auc',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constrai...
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=-1,
#                                            num_parallel_tree=None, ...),
#                    n_iter=20, n_jobs=1,
#                    param_distributions={'colsample_bytree': [0.8, 0.9],
#                                         'gamma': [0, 0.1, 0.2],
#                                         'learning_rate': [0.03, 0.05, 0.1],
#                                         'max_depth': [4, 5, 6, 7],
#                                         'min_child_weight': [3, 5],
#                                         'n_estimators': [200, 300],
#                                         'subsample': [0.8, 0.9]},
#                    random_state=37, scoring='roc_auc', verbose=1)

# %%
best_clf = random_search.best_estimator_

y_val_proba = best_clf.predict_proba(X_val)[:, 1]
val_auc = roc_auc_score(y_val, y_val_proba)

print(f"Validation AUC: {val_auc:.4f}")
print("Best parameters:")
for k, v in random_search.best_params_.items():
    print(f"  {k}: {v}")
# Out:
# Validation AUC: 0.9948
# Best parameters:
#   subsample: 0.8
#   n_estimators: 300
#   min_child_weight: 5
#   max_depth: 6
#   learning_rate: 0.1
#   gamma: 0.2
#   colsample_bytree: 0.9

# %%
best_params = random_search.best_params_

fine_grid = {}

for param, value in best_params.items():
    if param in ['learning_rate', 'subsample', 'colsample_bytree']:
        fine_grid[param] = sorted({
            max(0.01, value - 0.02),
            value,
            min(1.0, value + 0.02)
        })
    elif param in ['max_depth', 'min_child_weight']:
        fine_grid[param] = sorted({
            max(1, value - 1),
            value,
            value + 1
        })
    elif param == 'n_estimators':
        fine_grid[param] = sorted({
            max(50, value - 50),
            value,
            value + 50
        })
    elif param == 'gamma':
        fine_grid[param] = sorted({
            max(0, value - 0.1),
            value,
            value + 0.1
        })
    else:
        fine_grid[param] = [value]

param_combinations = list(
    dict(zip(fine_grid.keys(), v))
    for v in product(*fine_grid.values())
)

print(f"Phase 2: testing {len(param_combinations)} combinations")
# Out:
# Phase 2: testing 2187 combinations

# %%
best_auc = -np.inf
best_params_final = None
best_model = None

MAX_COMBOS = min(20, len(param_combinations))

for i, params in enumerate(param_combinations[:MAX_COMBOS]):
    print(f"[{i+1}/{MAX_COMBOS}] Testing params...")

    model = xgb.XGBClassifier(
        **params,
        objective='binary:logistic',
        eval_metric='auc',
        scale_pos_weight=scale_pos_weight,
        tree_method='hist',
        random_state=37,
        n_jobs=-1
    )

    # for the fine grid we use the whole train data to be as precise as possible 
    model.fit(X_train, y_train)

    y_val_proba = model.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_val_proba)

    print(f" AUC: {auc:.5f}")

    if auc > best_auc:
        best_auc = auc
        best_params_final = params
        best_model = model
        print("New best model found")

print("PHASE 2 RESULT:")
print(f"Best validation AUC: {best_auc:.5f}")
print("Best params:")
for k, v in best_params_final.items():
    print(f"  {k}: {v}")
# Out:
# [1/20] Testing params...
#  AUC: 0.99482
# New best model found
# [2/20] Testing params...
#  AUC: 0.99478
# [3/20] Testing params...
#  AUC: 0.99478
# [4/20] Testing params...
#  AUC: 0.99482
# New best model found
# [5/20] Testing params...
#  AUC: 0.99480
# [6/20] Testing params...
#  AUC: 0.99481
# [7/20] Testing params...
#  AUC: 0.99486
# New best model found
# [8/20] Testing params...
#  AUC: 0.99480
# [9/20] Testing params...
#  AUC: 0.99481
# [10/20] Testing params...
#  AUC: 0.99481
# [11/20] Testing params...
#  AUC: 0.99488
# New best model found
# [12/20] Testing params...
#  AUC: 0.99484
# [13/20] Testing params...
#  AUC: 0.99481
# [14/20] Testing params...
#  AUC: 0.99487
# [15/20] Testing params...
#  AUC: 0.99484
# [16/20] Testing params...
#  AUC: 0.99481
# [17/20] Testing params...
#  AUC: 0.99487
# [18/20] Testing params...
#  AUC: 0.99484
# [19/20] Testing params...
#  AUC: 0.99486
# [20/20] Testing params...
#  AUC: 0.99491
# New best model found
# PHASE 2 RESULT:
# Best validation AUC: 0.99491
# Best params:
#   subsample: 0.78
#   n_estimators: 250
#   min_child_weight: 4
#   max_depth: 5
#   learning_rate: 0.12000000000000001
#   gamma: 0.1
#   colsample_bytree: 0.9

# %%
y_val_proba = best_model.predict_proba(X_val)[:, 1]

thresholds = np.linspace(0.05, 0.95, 150)
f1_scores = []

for t in thresholds:
    y_pred = (y_val_proba >= t).astype(int)
    f1_scores.append(f1_score(y_val, y_pred))

best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f"Best threshold: {best_threshold:.4f}")
print(f"Best validation F1: {best_f1:.4f}")
# Out:
# Best threshold: 0.9500
# Best validation F1: 0.6430

# %%
with open("xgboost_best_clf_params.json", "w") as f:
    json.dump(best_params_final, f, indent=2)

# %%
best_model.save_model("xgboost_best_clf_model.json")

# %% [markdown]
# ### Final retrain and evaluation

# %%
# we combine train + validation to retrain with the hyperparameters we found
X_full = pd.concat([X_train, X_val])
y_full = pd.concat([y_train, y_val])

final_clf = xgb.XGBClassifier(
    **best_params_final,
    objective='binary:logistic',
    eval_metric='auc',
    scale_pos_weight=scale_pos_weight,
    tree_method='hist',
    random_state=37,
    n_jobs=-1
)

final_clf.fit(X_full, y_full)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=0.1, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.12000000000000001, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=250, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
# Predict test probabilities
y_test_proba = final_clf.predict_proba(X_test)[:, 1]
y_test_pred = (y_test_proba >= best_threshold).astype(int)

print("TEST AUC:", roc_auc_score(y_test, y_test_proba))
print(classification_report(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(f"Final F1 score : {f1_score(y_test, y_test_pred)}")
# Out:
# TEST AUC: 0.9939364933562427
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99   1391669
#            1       0.59      0.82      0.68     20043
#
#     accuracy                           0.99   1411712
#    macro avg       0.79      0.90      0.84   1411712
# weighted avg       0.99      0.99      0.99   1411712
#
# [[1380075   11594]
#  [   3649   16394]]
# Final F1 score : 0.6826424600778663

# %% [markdown]
# ## XGBoost Regressor

# %% [markdown]
# ### Reprepare data for regression

# %%
drop_features = ['commune_1', 'commune_2', 'flow']

X_train_reg, y_train_reg, X_val_reg, y_val_reg, X_test_reg, y_test_reg = build_train_test_val(df, 
                                                                      test_canton_ids=[3], 
                                                                      val_canton_ids=[19], 
                                                                      zero_drop_ratio=1, 
                                                                      random_state=37, 
                                                                      features=drop_features, 
                                                                      classify= False)
# Out:
# Splitting with canton [3] as test set:
# Total flows: 125,559
# Train size: 115,536 rows (92.0%)
# Test size: 10,023 rows (8.0%)
# Splitting with canton [19] as test set:
# Total flows: 115,536
# Train size: 95,182 rows (82.4%)
# Test size: 20,354 rows (17.6%)
# Dropping 100% of zeros in training data

# %%
X_train_reg = pd.get_dummies(
    X_train_reg,
    columns=["canton_code", "canton_code_2"],
    prefix=["canton_1", "canton_2"],
    drop_first=False
)

X_test_reg = pd.get_dummies(
    X_test_reg,
    columns=["canton_code", "canton_code_2"],
    prefix=["canton_1", "canton_2"],
    drop_first=False
)

X_val_reg = pd.get_dummies(
    X_val_reg,
    columns=["canton_code", "canton_code_2"],
    prefix=["canton_1", "canton_2"],
    drop_first=False
)

print(X_train_reg.shape)
print(X_test_reg.shape)
print(X_val_reg.shape)
# Out:
# (95182, 83)
# (10023, 80)
# (20354, 71)

# %%
X_val_reg  = X_val_reg.reindex(columns=X_train_reg.columns, fill_value=0)
X_test_reg = X_test_reg.reindex(columns=X_train_reg.columns, fill_value=0)

print(X_train_reg.shape, X_val_reg.shape, X_test_reg.shape)

assert X_train_reg.shape[1] == X_val_reg.shape[1] == X_test_reg.shape[1]
assert X_train_reg.columns.equals(X_val_reg.columns)
assert X_train_reg.columns.equals(X_test_reg.columns)
# Out:
# (95182, 83) (20354, 83) (10023, 83)

# %%
print(X_train_reg.shape, X_val_reg.shape, X_test_reg.shape)
print(y_train_reg.describe())
# Out:
# (95182, 83) (20354, 83) (10023, 83)
# count    95182.000000
# mean        43.375659
# std        176.994846
# min          5.000000
# 25%          7.000000
# 50%         12.000000
# 75%         28.000000
# max      11129.000000
# Name: flow, dtype: float64

# %%
y_train_reg_log = np.log1p(y_train_reg)
y_val_reg_log   = np.log1p(y_val_reg)
y_test_reg_log  = np.log1p(y_test_reg)

# %%
reg = xgb.XGBRegressor(
    objective="reg:squarederror",
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
)

reg.fit(
    X_train_reg,
    y_train_reg_log,
    eval_set=[(X_val_reg, y_val_reg_log)],
    verbose=True
)

y_val_pred_log = reg.predict(X_val_reg)
y_val_pred = np.expm1(y_val_pred_log)

y_val_true = y_val_reg

mae  = mean_absolute_error(y_val_true, y_val_pred)
mse = mean_squared_error(y_val_true, y_val_pred)
rmse = np.sqrt(mse)

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# [0]	validation_0-rmse:0.87937
# [1]	validation_0-rmse:0.85821
# [2]	validation_0-rmse:0.84137
# [3]	validation_0-rmse:0.82497
# [4]	validation_0-rmse:0.80760
# [5]	validation_0-rmse:0.79108
# [6]	validation_0-rmse:0.77589
# [7]	validation_0-rmse:0.76108
# [8]	validation_0-rmse:0.74756
# [9]	validation_0-rmse:0.73569
# [10]	validation_0-rmse:0.72407
# [11]	validation_0-rmse:0.71329
# [12]	validation_0-rmse:0.70291
# [13]	validation_0-rmse:0.69452
# [14]	validation_0-rmse:0.68603
# [15]	validation_0-rmse:0.67834
# [16]	validation_0-rmse:0.67004
# [17]	validation_0-rmse:0.66306
# [18]	validation_0-rmse:0.65645
# [19]	validation_0-rmse:0.65022
# [20]	validation_0-rmse:0.64427
# [21]	validation_0-rmse:0.64101
# [22]	validation_0-rmse:0.63531
# [23]	validation_0-rmse:0.63094
# [24]	validation_0-rmse:0.62652
# [25]	validation_0-rmse:0.62187
# [26]	validation_0-rmse:0.61755
# [27]	validation_0-rmse:0.61476
# [28]	validation_0-rmse:0.61110
# [29]	validation_0-rmse:0.60815
# [30]	validation_0-rmse:0.60489
# [31]	validation_0-rmse:0.60170
# [32]	validation_0-rmse:0.59857
# [33]	validation_0-rmse:0.59610
# [34]	validation_0-rmse:0.59368
# [35]	validation_0-rmse:0.59116
# [36]	validation_0-rmse:0.58920
# [37]	validation_0-rmse:0.58736
# [38]	validation_0-rmse:0.58522
# [39]	validation_0-rmse:0.58270
# [40]	validation_0-rmse:0.58109
# [41]	validation_0-rmse:0.57961
# [42]	validation_0-rmse:0.57801
# [43]	validation_0-rmse:0.57667
# [44]	validation_0-rmse:0.57513
# [45]	validation_0-rmse:0.57396
# [46]	validation_0-rmse:0.57274
# [47]	validation_0-rmse:0.57150
# [48]	validation_0-rmse:0.57034
# [49]	validation_0-rmse:0.56945
# [50]	validation_0-rmse:0.56826
# [51]	validation_0-rmse:0.56731
# [52]	validation_0-rmse:0.56663
# [53]	validation_0-rmse:0.56593
# [54]	validation_0-rmse:0.56512
# [55]	validation_0-rmse:0.56418
# [56]	validation_0-rmse:0.56339
# [57]	validation_0-rmse:0.56215
# [58]	validation_0-rmse:0.56165
# [59]	validation_0-rmse:0.56143
# [60]	validation_0-rmse:0.56054
# [61]	validation_0-rmse:0.56010
# [62]	validation_0-rmse:0.55952
# [63]	validation_0-rmse:0.55911
# [64]	validation_0-rmse:0.55843
# [65]	validation_0-rmse:0.55798
# [66]	validation_0-rmse:0.55771
# [67]	validation_0-rmse:0.55731
# [68]	validation_0-rmse:0.55654
# [69]	validation_0-rmse:0.55632
# [70]	validation_0-rmse:0.55589
# [71]	validation_0-rmse:0.55569
# [72]	validation_0-rmse:0.55513
# [73]	validation_0-rmse:0.55492
# [74]	validation_0-rmse:0.55463
# [75]	validation_0-rmse:0.55435
# [76]	validation_0-rmse:0.55397
# [77]	validation_0-rmse:0.55337
# [78]	validation_0-rmse:0.55316
# [79]	validation_0-rmse:0.55301
# [80]	validation_0-rmse:0.55296
# [81]	validation_0-rmse:0.55273
# [82]	validation_0-rmse:0.55241
# [83]	validation_0-rmse:0.55231
# [84]	validation_0-rmse:0.55215
# [85]	validation_0-rmse:0.55198
# [86]	validation_0-rmse:0.55191
# [87]	validation_0-rmse:0.55176
# [88]	validation_0-rmse:0.55161
# [89]	validation_0-rmse:0.55156
# [90]	validation_0-rmse:0.55139
# [91]	validation_0-rmse:0.55139
# [92]	validation_0-rmse:0.55141
# [93]	validation_0-rmse:0.55126
# [94]	validation_0-rmse:0.55127
# [95]	validation_0-rmse:0.55113
# [96]	validation_0-rmse:0.55099
# [97]	validation_0-rmse:0.55080
# [98]	validation_0-rmse:0.55053
# [99]	validation_0-rmse:0.55052
# [100]	validation_0-rmse:0.55047
# [101]	validation_0-rmse:0.55030
# [102]	validation_0-rmse:0.55009
# [103]	validation_0-rmse:0.55009
# [104]	validation_0-rmse:0.55010
# [105]	validation_0-rmse:0.55025
# [106]	validation_0-rmse:0.55018
# [107]	validation_0-rmse:0.54992
# [108]	validation_0-rmse:0.54983
# [109]	validation_0-rmse:0.54976
# [110]	validation_0-rmse:0.54974
# [111]	validation_0-rmse:0.54967
# [112]	validation_0-rmse:0.54956
# [113]	validation_0-rmse:0.54954
# [114]	validation_0-rmse:0.54956
# [115]	validation_0-rmse:0.54970
# [116]	validation_0-rmse:0.54964
# [117]	validation_0-rmse:0.54969
# [118]	validation_0-rmse:0.54955
# [119]	validation_0-rmse:0.54950
# [120]	validation_0-rmse:0.54949
# [121]	validation_0-rmse:0.54958
# [122]	validation_0-rmse:0.54937
# [123]	validation_0-rmse:0.54856
# [124]	validation_0-rmse:0.54858
# [125]	validation_0-rmse:0.54849
# [126]	validation_0-rmse:0.54846
# [127]	validation_0-rmse:0.54851
# [128]	validation_0-rmse:0.54868
# [129]	validation_0-rmse:0.54859
# [130]	validation_0-rmse:0.54862
# [131]	validation_0-rmse:0.54849
# [132]	validation_0-rmse:0.54844
# [133]	validation_0-rmse:0.54845
# [134]	validation_0-rmse:0.54859
# [135]	validation_0-rmse:0.54814
# [136]	validation_0-rmse:0.54816
# [137]	validation_0-rmse:0.54807
# [138]	validation_0-rmse:0.54806
# [139]	validation_0-rmse:0.54814
# [140]	validation_0-rmse:0.54810
# [141]	validation_0-rmse:0.54805
# [142]	validation_0-rmse:0.54789
# [143]	validation_0-rmse:0.54786
# [144]	validation_0-rmse:0.54780
# [145]	validation_0-rmse:0.54784
# [146]	validation_0-rmse:0.54778
# [147]	validation_0-rmse:0.54771
# [148]	validation_0-rmse:0.54768
# [149]	validation_0-rmse:0.54756
# [150]	validation_0-rmse:0.54750
# [151]	validation_0-rmse:0.54741
# [152]	validation_0-rmse:0.54742
# [153]	validation_0-rmse:0.54718
# [154]	validation_0-rmse:0.54706
# [155]	validation_0-rmse:0.54721
# [156]	validation_0-rmse:0.54715
# [157]	validation_0-rmse:0.54719
# [158]	validation_0-rmse:0.54743
# [159]	validation_0-rmse:0.54745
# [160]	validation_0-rmse:0.54739
# [161]	validation_0-rmse:0.54727
# [162]	validation_0-rmse:0.54725
# [163]	validation_0-rmse:0.54723
# [164]	validation_0-rmse:0.54724
# [165]	validation_0-rmse:0.54718
# [166]	validation_0-rmse:0.54718
# [167]	validation_0-rmse:0.54713
# [168]	validation_0-rmse:0.54712
# [169]	validation_0-rmse:0.54704
# [170]	validation_0-rmse:0.54699
# [171]	validation_0-rmse:0.54699
# [172]	validation_0-rmse:0.54700
# [173]	validation_0-rmse:0.54707
# [174]	validation_0-rmse:0.54708
# [175]	validation_0-rmse:0.54699
# [176]	validation_0-rmse:0.54680
# [177]	validation_0-rmse:0.54668
# [178]	validation_0-rmse:0.54668
# [179]	validation_0-rmse:0.54658
# [180]	validation_0-rmse:0.54653
# [181]	validation_0-rmse:0.54653
# [182]	validation_0-rmse:0.54655
# [183]	validation_0-rmse:0.54664
# [184]	validation_0-rmse:0.54663
# [185]	validation_0-rmse:0.54661
# [186]	validation_0-rmse:0.54663
# [187]	validation_0-rmse:0.54661
# [188]	validation_0-rmse:0.54645
# [189]	validation_0-rmse:0.54625
# [190]	validation_0-rmse:0.54616
# [191]	validation_0-rmse:0.54608
# [192]	validation_0-rmse:0.54610
# [193]	validation_0-rmse:0.54605
# [194]	validation_0-rmse:0.54607
# [195]	validation_0-rmse:0.54612
# [196]	validation_0-rmse:0.54601
# [197]	validation_0-rmse:0.54601
# [198]	validation_0-rmse:0.54590
# [199]	validation_0-rmse:0.54601
# [200]	validation_0-rmse:0.54587
# [201]	validation_0-rmse:0.54587
# [202]	validation_0-rmse:0.54579
# [203]	validation_0-rmse:0.54581
# [204]	validation_0-rmse:0.54585
# [205]	validation_0-rmse:0.54588
# [206]	validation_0-rmse:0.54582
# [207]	validation_0-rmse:0.54585
# [208]	validation_0-rmse:0.54588
# [209]	validation_0-rmse:0.54586
# [210]	validation_0-rmse:0.54594
# [211]	validation_0-rmse:0.54593
# [212]	validation_0-rmse:0.54596
# [213]	validation_0-rmse:0.54592
# [214]	validation_0-rmse:0.54574
# [215]	validation_0-rmse:0.54573
# [216]	validation_0-rmse:0.54574
# [217]	validation_0-rmse:0.54601
# [218]	validation_0-rmse:0.54598
# [219]	validation_0-rmse:0.54594
# [220]	validation_0-rmse:0.54605
# [221]	validation_0-rmse:0.54602
# [222]	validation_0-rmse:0.54603
# [223]	validation_0-rmse:0.54594
# [224]	validation_0-rmse:0.54586
# [225]	validation_0-rmse:0.54585
# [226]	validation_0-rmse:0.54572
# [227]	validation_0-rmse:0.54573
# [228]	validation_0-rmse:0.54573
# [229]	validation_0-rmse:0.54576
# [230]	validation_0-rmse:0.54578
# [231]	validation_0-rmse:0.54596
# [232]	validation_0-rmse:0.54595
# [233]	validation_0-rmse:0.54599
# [234]	validation_0-rmse:0.54611
# [235]	validation_0-rmse:0.54614
# [236]	validation_0-rmse:0.54622
# [237]	validation_0-rmse:0.54612
# [238]	validation_0-rmse:0.54608
# [239]	validation_0-rmse:0.54597
# [240]	validation_0-rmse:0.54596
# [241]	validation_0-rmse:0.54596
# [242]	validation_0-rmse:0.54587
# [243]	validation_0-rmse:0.54583
# [244]	validation_0-rmse:0.54587
# [245]	validation_0-rmse:0.54569
# [246]	validation_0-rmse:0.54572
# [247]	validation_0-rmse:0.54581
# [248]	validation_0-rmse:0.54583
# [249]	validation_0-rmse:0.54584
# [250]	validation_0-rmse:0.54580
# [251]	validation_0-rmse:0.54574
# [252]	validation_0-rmse:0.54567
# [253]	validation_0-rmse:0.54564
# [254]	validation_0-rmse:0.54559
# [255]	validation_0-rmse:0.54523
# [256]	validation_0-rmse:0.54534
# [257]	validation_0-rmse:0.54530
# [258]	validation_0-rmse:0.54531
# [259]	validation_0-rmse:0.54543
# [260]	validation_0-rmse:0.54546
# [261]	validation_0-rmse:0.54545
# [262]	validation_0-rmse:0.54547
# [263]	validation_0-rmse:0.54551
# [264]	validation_0-rmse:0.54547
# [265]	validation_0-rmse:0.54548
# [266]	validation_0-rmse:0.54547
# [267]	validation_0-rmse:0.54547
# [268]	validation_0-rmse:0.54549
# [269]	validation_0-rmse:0.54564
# [270]	validation_0-rmse:0.54555
# [271]	validation_0-rmse:0.54568
# [272]	validation_0-rmse:0.54565
# [273]	validation_0-rmse:0.54581
# [274]	validation_0-rmse:0.54582
# [275]	validation_0-rmse:0.54581
# [276]	validation_0-rmse:0.54580
# [277]	validation_0-rmse:0.54577
# [278]	validation_0-rmse:0.54588
# [279]	validation_0-rmse:0.54586
# [280]	validation_0-rmse:0.54592
# [281]	validation_0-rmse:0.54587
# [282]	validation_0-rmse:0.54594
# [283]	validation_0-rmse:0.54591
# [284]	validation_0-rmse:0.54583
# [285]	validation_0-rmse:0.54582
# [286]	validation_0-rmse:0.54587
# [287]	validation_0-rmse:0.54579
# [288]	validation_0-rmse:0.54568
# [289]	validation_0-rmse:0.54566
# [290]	validation_0-rmse:0.54564
# [291]	validation_0-rmse:0.54552
# [292]	validation_0-rmse:0.54547
# [293]	validation_0-rmse:0.54547
# [294]	validation_0-rmse:0.54570
# [295]	validation_0-rmse:0.54577
# [296]	validation_0-rmse:0.54583
# [297]	validation_0-rmse:0.54584
# [298]	validation_0-rmse:0.54583
# [299]	validation_0-rmse:0.54566
# [300]	validation_0-rmse:0.54565
# [301]	validation_0-rmse:0.54570
# [302]	validation_0-rmse:0.54572
# [303]	validation_0-rmse:0.54582
# [304]	validation_0-rmse:0.54579
# [305]	validation_0-rmse:0.54586
# [306]	validation_0-rmse:0.54554
# [307]	validation_0-rmse:0.54568
# [308]	validation_0-rmse:0.54569
# [309]	validation_0-rmse:0.54554
# [310]	validation_0-rmse:0.54559
# [311]	validation_0-rmse:0.54530
# [312]	validation_0-rmse:0.54538
# [313]	validation_0-rmse:0.54538
# [314]	validation_0-rmse:0.54542
# [315]	validation_0-rmse:0.54540
# [316]	validation_0-rmse:0.54546
# [317]	validation_0-rmse:0.54554
# [318]	validation_0-rmse:0.54552
# [319]	validation_0-rmse:0.54558
# [320]	validation_0-rmse:0.54558
# [321]	validation_0-rmse:0.54553
# [322]	validation_0-rmse:0.54546
# [323]	validation_0-rmse:0.54548
# [324]	validation_0-rmse:0.54527
# [325]	validation_0-rmse:0.54538
# [326]	validation_0-rmse:0.54536
# [327]	validation_0-rmse:0.54532
# [328]	validation_0-rmse:0.54529
# [329]	validation_0-rmse:0.54529
# [330]	validation_0-rmse:0.54531
# [331]	validation_0-rmse:0.54523
# [332]	validation_0-rmse:0.54536
# [333]	validation_0-rmse:0.54535
# [334]	validation_0-rmse:0.54532
# [335]	validation_0-rmse:0.54521
# [336]	validation_0-rmse:0.54534
# [337]	validation_0-rmse:0.54540
# [338]	validation_0-rmse:0.54533
# [339]	validation_0-rmse:0.54539
# [340]	validation_0-rmse:0.54538
# [341]	validation_0-rmse:0.54550
# [342]	validation_0-rmse:0.54550
# [343]	validation_0-rmse:0.54566
# [344]	validation_0-rmse:0.54564
# [345]	validation_0-rmse:0.54565
# [346]	validation_0-rmse:0.54559
# [347]	validation_0-rmse:0.54555
# [348]	validation_0-rmse:0.54558
# [349]	validation_0-rmse:0.54550
# [350]	validation_0-rmse:0.54556
# [351]	validation_0-rmse:0.54554
# [352]	validation_0-rmse:0.54550
# [353]	validation_0-rmse:0.54544
# [354]	validation_0-rmse:0.54549
# [355]	validation_0-rmse:0.54544
# [356]	validation_0-rmse:0.54535
# [357]	validation_0-rmse:0.54531
# [358]	validation_0-rmse:0.54532
# [359]	validation_0-rmse:0.54535
# [360]	validation_0-rmse:0.54534
# [361]	validation_0-rmse:0.54533
# [362]	validation_0-rmse:0.54537
# [363]	validation_0-rmse:0.54539
# [364]	validation_0-rmse:0.54551
# [365]	validation_0-rmse:0.54552
# [366]	validation_0-rmse:0.54544
# [367]	validation_0-rmse:0.54562
# [368]	validation_0-rmse:0.54569
# [369]	validation_0-rmse:0.54574
# [370]	validation_0-rmse:0.54576
# [371]	validation_0-rmse:0.54582
# [372]	validation_0-rmse:0.54584
# [373]	validation_0-rmse:0.54581
# [374]	validation_0-rmse:0.54583
# [375]	validation_0-rmse:0.54577
# [376]	validation_0-rmse:0.54582
# [377]	validation_0-rmse:0.54583
# [378]	validation_0-rmse:0.54575
# [379]	validation_0-rmse:0.54583
# [380]	validation_0-rmse:0.54579
# [381]	validation_0-rmse:0.54579
# [382]	validation_0-rmse:0.54593
# [383]	validation_0-rmse:0.54596
# [384]	validation_0-rmse:0.54599
# [385]	validation_0-rmse:0.54600
# [386]	validation_0-rmse:0.54594
# [387]	validation_0-rmse:0.54596
# [388]	validation_0-rmse:0.54598
# [389]	validation_0-rmse:0.54601
# [390]	validation_0-rmse:0.54591
# [391]	validation_0-rmse:0.54588
# [392]	validation_0-rmse:0.54590
# [393]	validation_0-rmse:0.54576
# [394]	validation_0-rmse:0.54578
# [395]	validation_0-rmse:0.54579
# [396]	validation_0-rmse:0.54568
# [397]	validation_0-rmse:0.54554
# [398]	validation_0-rmse:0.54556
# [399]	validation_0-rmse:0.54545
# [400]	validation_0-rmse:0.54544
# [401]	validation_0-rmse:0.54543
# [402]	validation_0-rmse:0.54557
# [403]	validation_0-rmse:0.54562
# [404]	validation_0-rmse:0.54565
# [405]	validation_0-rmse:0.54563
# [406]	validation_0-rmse:0.54557
# [407]	validation_0-rmse:0.54559
# [408]	validation_0-rmse:0.54563
# [409]	validation_0-rmse:0.54563
# [410]	validation_0-rmse:0.54571
# [411]	validation_0-rmse:0.54566
# [412]	validation_0-rmse:0.54575
# [413]	validation_0-rmse:0.54565
# [414]	validation_0-rmse:0.54564
# [415]	validation_0-rmse:0.54562
# [416]	validation_0-rmse:0.54571
# [417]	validation_0-rmse:0.54585
# [418]	validation_0-rmse:0.54583
# [419]	validation_0-rmse:0.54574
# [420]	validation_0-rmse:0.54571
# [421]	validation_0-rmse:0.54572
# [422]	validation_0-rmse:0.54579
# [423]	validation_0-rmse:0.54578
# [424]	validation_0-rmse:0.54581
# [425]	validation_0-rmse:0.54582
# [426]	validation_0-rmse:0.54578
# [427]	validation_0-rmse:0.54590
# [428]	validation_0-rmse:0.54583
# [429]	validation_0-rmse:0.54584
# [430]	validation_0-rmse:0.54586
# [431]	validation_0-rmse:0.54581
# [432]	validation_0-rmse:0.54584
# [433]	validation_0-rmse:0.54593
# [434]	validation_0-rmse:0.54595
# [435]	validation_0-rmse:0.54595
# [436]	validation_0-rmse:0.54600
# [437]	validation_0-rmse:0.54610
# [438]	validation_0-rmse:0.54612
# [439]	validation_0-rmse:0.54610
# [440]	validation_0-rmse:0.54645
# [441]	validation_0-rmse:0.54634
# [442]	validation_0-rmse:0.54632
# [443]	validation_0-rmse:0.54646
# [444]	validation_0-rmse:0.54650
# [445]	validation_0-rmse:0.54650
# [446]	validation_0-rmse:0.54645
# [447]	validation_0-rmse:0.54643
# [448]	validation_0-rmse:0.54644
# [449]	validation_0-rmse:0.54644
# [450]	validation_0-rmse:0.54650
# [451]	validation_0-rmse:0.54648
# [452]	validation_0-rmse:0.54645
# [453]	validation_0-rmse:0.54650
# [454]	validation_0-rmse:0.54662
# [455]	validation_0-rmse:0.54669
# [456]	validation_0-rmse:0.54661
# [457]	validation_0-rmse:0.54665
# [458]	validation_0-rmse:0.54679
# [459]	validation_0-rmse:0.54682
# [460]	validation_0-rmse:0.54684
# [461]	validation_0-rmse:0.54686
# [462]	validation_0-rmse:0.54664
# [463]	validation_0-rmse:0.54656
# [464]	validation_0-rmse:0.54654
# [465]	validation_0-rmse:0.54654
# [466]	validation_0-rmse:0.54654
# [467]	validation_0-rmse:0.54640
# [468]	validation_0-rmse:0.54643
# [469]	validation_0-rmse:0.54646
# [470]	validation_0-rmse:0.54646
# [471]	validation_0-rmse:0.54644
# [472]	validation_0-rmse:0.54641
# [473]	validation_0-rmse:0.54639
# [474]	validation_0-rmse:0.54642
# [475]	validation_0-rmse:0.54639
# [476]	validation_0-rmse:0.54639
# [477]	validation_0-rmse:0.54640
# [478]	validation_0-rmse:0.54637
# [479]	validation_0-rmse:0.54638
# [480]	validation_0-rmse:0.54638
# [481]	validation_0-rmse:0.54638
# [482]	validation_0-rmse:0.54637
# [483]	validation_0-rmse:0.54636
# [484]	validation_0-rmse:0.54634
# [485]	validation_0-rmse:0.54621
# [486]	validation_0-rmse:0.54621
# [487]	validation_0-rmse:0.54616
# [488]	validation_0-rmse:0.54616
# [489]	validation_0-rmse:0.54617
# [490]	validation_0-rmse:0.54620
# [491]	validation_0-rmse:0.54626
# [492]	validation_0-rmse:0.54629
# [493]	validation_0-rmse:0.54632
# [494]	validation_0-rmse:0.54633
# [495]	validation_0-rmse:0.54647
# [496]	validation_0-rmse:0.54636
# [497]	validation_0-rmse:0.54636
# [498]	validation_0-rmse:0.54643
# [499]	validation_0-rmse:0.54641
# MAE: 12.501787080387125
# RMSE: 38.38496448886762

# %% [markdown]
# ### Grid search

# %%
# We do again a grid search in 2 phases 

param_grid_reg = {
    "n_estimators": [200, 400, 600],
    "max_depth": [4, 6, 8],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.7, 0.8, 0.9],
    "colsample_bytree": [0.7, 0.8, 0.9],
    "min_child_weight": [1, 3, 5],
    "gamma": [0, 0.1, 0.3]
}


reg_base = xgb.XGBRegressor(
    objective="reg:squarederror",
    random_state=37,
    n_jobs=1
)

random_search_reg = RandomizedSearchCV(
    estimator=reg_base,
    param_distributions=param_grid_reg,
    n_iter=25,
    scoring="neg_root_mean_squared_error",  # RMSE on log-scale
    cv=3,
    refit=True,
    random_state=37,
    n_jobs=1,
    verbose=1
)

random_search_reg.fit(X_train_reg, y_train_reg_log)

print("Best CV RMSE (log):", -random_search_reg.best_score_)
print("Best params:")
for k, v in random_search_reg.best_params_.items():
    print(f"  {k}: {v}")
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best CV RMSE (log): 0.45553308150695043
# Best params:
#   subsample: 0.9
#   n_estimators: 600
#   min_child_weight: 3
#   max_depth: 6
#   learning_rate: 0.1
#   gamma: 0.3
#   colsample_bytree: 0.8

# %%
# validation for phase 1

best_reg_phase1 = random_search_reg.best_estimator_

y_val_pred_log = best_reg_phase1.predict(X_val_reg)
y_val_pred = np.expm1(y_val_pred_log)

mae = mean_absolute_error(y_val_reg, y_val_pred)
rmse = np.sqrt(mean_squared_error(y_val_reg, y_val_pred))

print("Phase 1 MAE:", mae)
print("Phase 1 RMSE:", rmse)
# Out:
# Phase 1 MAE: 12.883836392594002
# Phase 1 RMSE: 39.80515398937253

# %%
# phase 2: we tune around the best parameters we found in phase 1

best_params = random_search_reg.best_params_

fine_grid = {}

for param, value in best_params.items():
    if param in ["learning_rate", "subsample", "colsample_bytree"]:
        fine_grid[param] = [max(0.01, value - 0.02), value, min(1.0, value + 0.02)]
    elif param in ["max_depth", "min_child_weight"]:
        fine_grid[param] = [max(1, value - 1), value, value + 1]
    elif param == "n_estimators":
        fine_grid[param] = [max(100, value - 100), value, value + 100]
    elif param == "gamma":
        fine_grid[param] = [max(0, value - 0.1), value, value + 0.1]
    else:
        fine_grid[param] = [value]

# %%
best_rmse = float("inf")
best_reg_final = None
best_params_final = None

param_combinations = [
    dict(zip(fine_grid.keys(), v))
    for v in product(*fine_grid.values())
]

for i, params in enumerate(param_combinations[:25]):
    print(f"Testing combo {i+1}/{min(20, len(param_combinations))}")

    reg = xgb.XGBRegressor(
        objective="reg:squarederror",
        random_state=37,
        n_jobs=-1,
        **params
    )

    reg.fit(X_train_reg, y_train_reg_log)
    y_pred_log = reg.predict(X_val_reg)
    y_pred = np.expm1(y_pred_log)

    rmse = np.sqrt(mean_squared_error(y_val_reg, y_pred))

    if rmse < best_rmse:
        best_rmse = rmse
        best_reg_final = reg
        best_params_final = params
        print(f"  New best RMSE: {rmse:.2f}")
# Out:
# Testing combo 1/20
#   New best RMSE: 38.72
# Testing combo 2/20
#   New best RMSE: 38.01
# Testing combo 3/20
# Testing combo 4/20
# Testing combo 5/20
# Testing combo 6/20
# Testing combo 7/20
#   New best RMSE: 37.92
# Testing combo 8/20
# Testing combo 9/20
# Testing combo 10/20
# Testing combo 11/20
# Testing combo 12/20
# Testing combo 13/20
# Testing combo 14/20
# Testing combo 15/20
# Testing combo 16/20
# Testing combo 17/20
# Testing combo 18/20
# Testing combo 19/20
# Testing combo 20/20
# Testing combo 21/20
# Testing combo 22/20
# Testing combo 23/20
# Testing combo 24/20
# Testing combo 25/20

# %%
with open("xgboost_best_reg_params.json", "w") as f:
    json.dump(best_params_final, f, indent=2)

# %%
best_reg_final.save_model("xgboost_best_reg_model.json")

# %% [markdown]
# ### Final retrain

# %%
X_full_reg = pd.concat([X_train_reg, X_val_reg])
y_full_reg = pd.concat([y_train_reg, y_val_reg])

best_reg_final.fit(
    X_full_reg,
    np.log1p(y_full_reg)
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.78, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.4, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.08, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=2, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
predicred_reg_log = best_reg_final.predict(X_test_reg)
predicted_reg = np.expm1(predicred_reg_log)

print(y_test_reg.shape)
print(predicted_reg.shape)

r2_reg = r2_score(y_test_reg, predicted_reg)
rmse_reg = np.sqrt(mean_squared_error(y_test_reg, predicted_reg))
mae_reg = np.mean(np.abs(y_test_reg - predicted_reg))
correlation_reg = np.corrcoef(y_test_reg, predicted_reg)[0, 1]
    
print(f"R² Score: {r2_reg:.3f}")
print(f"RMSE: {rmse_reg:.1f} commuters")
print(f"MAE: {mae_reg:.1f} commuters")
print(f"Pearson Correlation: {correlation_reg:.3f}")
# Out:
# (20043,)
# (20043,)
# R² Score: 0.776
# RMSE: 57.9 commuters
# MAE: 16.5 commuters
# Pearson Correlation: 0.909
